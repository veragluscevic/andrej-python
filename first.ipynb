# %% [markdown]
# # Title

# %% [markdown]
# Python imports we'll need later...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def damped(x,f=1,k=1):
    value = np.exp(-x/k)*np.sin(x*f)
    return value

# %%
damped(5)
# Out:
# -0.006461180938816702

# %%
x = np.linspace(0,200,1000)

# %%
y10=damped(x,f=1,k=10)
y100=damped(x,f=1,k=20)

# %%
plt.plot(x,y100) 
plt.plot(x,y10)

# %%
def f(x):
    value = (np.arccosh(x)+np.sinc(x))/2
    return value

# %%
y = f(x)
# Out:
# /var/folders/ff/vj2d13hd2s34db7c05qfcvkm0000gp/T/ipykernel_47543/1763696067.py:2: RuntimeWarning: invalid value encountered in arccosh
#   value = (np.arccosh(x)+np.sinc(x))/2

# %%
plt.plot(x,y)

# %%
x = np.linspace(-20,20,100000)

# %%
def f(x):
    value = np.sinc(x**2)
    return value
