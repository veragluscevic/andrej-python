# %% [markdown]
# # Title

# %% [markdown]
# Python imports we'll need later...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def damped(x,f=1,k=1):
    value = np.exp(-x/k)*np.sin(x*f)
    return value

# %%
damped(5)
# Out:
# -0.006461180938816702

# %%
x = np.linspace(0,200,1000)

# %%
y10=damped(x,f=1,k=10)
y100=damped(x,f=1,k=20)

# %%
plt.plot(x,y100) 
plt.plot(x,y10)

# %%
def f(x):
    value = np.sinh((2**x+x**2)/2)
    return value

# %%
y = f(x)
# Out:
# /var/folders/ff/vj2d13hd2s34db7c05qfcvkm0000gp/T/ipykernel_34753/245332409.py:2: RuntimeWarning: overflow encountered in sinh
#   value = np.sinh((2**x+x**2)/2)

# %%
plt.plot()
